# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuvahre/coders-cave-internship/blob/main/normal_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/Hackathon_Ideal_Data.csv")

# %%
df.head()
# Out:
#   MONTH STORECODE  QTY  VALUE                GRP               SGRP  \
# 0    M1        P1   25     83  HAIR CONDITIONERS  HAIR CONDITIONERS
# 1    M1        P1    6     22  HAIR CONDITIONERS  HAIR CONDITIONERS
# 2    M1        P1    4     15  HAIR CONDITIONERS  HAIR CONDITIONERS
# 3    M1        P1   15     60  HAIR CONDITIONERS  HAIR CONDITIONERS
# 4    M1        P2    0      0  HAIR CONDITIONERS  HAIR CONDITIONERS
#
#                SSGRP                         CMP         MBRD  \
# 0  HAIR CONDITIONERS  HINDUSTAN UNILEVER LIMITED         DOVE
# 1  HAIR CONDITIONERS  HINDUSTAN UNILEVER LIMITED         DOVE
# 2  HAIR CONDITIONERS  HINDUSTAN UNILEVER LIMITED         DOVE
# 3  HAIR CONDITIONERS               L'OREAL INDIA      GARNIER
# 4  HAIR CONDITIONERS  HINDUSTAN UNILEVER LIMITED  CLINIC PLUS
#
#                      BRD
# 0  DOVE HAIR FALL RESCUE
# 1    DOVE INTENSE REPAIR
# 2   DOVE OXYGEN MOISTURE
# 3                FRUCTIS
# 4            CLINIC PLUS

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# MONTH        0
# STORECODE    0
# QTY          0
# VALUE        0
# GRP          0
# SGRP         0
# SSGRP        0
# CMP          0
# MBRD         0
# BRD          0
# dtype: int64

# %%
df1=pd.read_csv("/content/drive/MyDrive/Hackathon_Working_Data.csv")

# %%
df1
# Out:
#       MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  VALUE  PRICE  \
# 0        M1        N1    4    T375     225.0  1.0  225.0  225.0
# 1        M1        N1    4    T379      95.0  1.0   95.0   95.0
# 2        M1        N1    4    T381      10.0  1.0   10.0   10.0
# 3        M1        N1    4    T382     108.0  1.0  108.0  108.0
# 4        M1        N1    4    T384      19.0  1.0   19.0   19.0
# ...     ...       ...  ...     ...       ...  ...    ...    ...
# 26980    M3       N10   31   T5999      10.0  1.0   10.0   10.0
# 26981    M3       N10   31   T6007      88.0  1.0   10.0   10.0
# 26982    M3       N10   31   T6007      88.0  2.0   20.0   10.0
# 26983    M3       N10   31   T6007      88.0  1.0   58.0   58.0
# 26984    M3       N10   31   T6013      15.0  1.0   15.0   15.0
#
#                               GRP                     SGRP  \
# 0            BUTTER MARGR  (4/94)                   BUTTER
# 1         CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS
# ...

# %%
df1.duplicated().sum()
# Out:
# 90

# %%
df1=df1.drop_duplicates()

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.isnull().sum()
# Out:
# MONTH        0
# STORECODE    0
# DAY          0
# BILL_ID      0
# BILL_AMT     0
# QTY          0
# VALUE        0
# PRICE        0
# GRP          0
# SGRP         0
# SSGRP        0
# CMP          0
# MBRD         0
# BRD          0
# dtype: int64

# %%
df2=pd.read_csv("/content/drive/MyDrive/Hackathon_Validation_Data.csv")

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.isnull().sum()
# Out:
# ID           0
# STORECODE    0
# MONTH        0
# GRP          0
# dtype: int64

# %%
df3=pd.read_csv("/content/drive/MyDrive/Hackathon_Mapping_File.csv")

# %%
df.columns,df1.columns,df2.columns,df3.columns,
# Out:
# (Index(['MONTH', 'STORECODE', 'QTY', 'VALUE', 'GRP', 'SGRP', 'SSGRP', 'CMP',
#         'MBRD', 'BRD'],
#        dtype='object'),
#  Index(['MONTH', 'STORECODE', 'DAY', 'BILL_ID', 'BILL_AMT', 'QTY', 'VALUE',
#         'PRICE', 'GRP', 'SGRP', 'SSGRP', 'CMP', 'MBRD', 'BRD'],
#        dtype='object'),
#  Index(['ID', 'STORECODE', 'MONTH', 'GRP'], dtype='object'),
#  Index(['File Name', 'Column Name', 'Column Description'], dtype='object'))

# %%
df1
# Out:
#       MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  VALUE  PRICE  \
# 0        M1        N1    4    T375     225.0  1.0  225.0  225.0
# 1        M1        N1    4    T379      95.0  1.0   95.0   95.0
# 2        M1        N1    4    T381      10.0  1.0   10.0   10.0
# 3        M1        N1    4    T382     108.0  1.0  108.0  108.0
# 4        M1        N1    4    T384      19.0  1.0   19.0   19.0
# ...     ...       ...  ...     ...       ...  ...    ...    ...
# 26980    M3       N10   31   T5999      10.0  1.0   10.0   10.0
# 26981    M3       N10   31   T6007      88.0  1.0   10.0   10.0
# 26982    M3       N10   31   T6007      88.0  2.0   20.0   10.0
# 26983    M3       N10   31   T6007      88.0  1.0   58.0   58.0
# 26984    M3       N10   31   T6013      15.0  1.0   15.0   15.0
#
#                               GRP                     SGRP  \
# 0            BUTTER MARGR  (4/94)                   BUTTER
# 1         CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS
# ...

# %%
df1.describe(include='all')
# Out:
#         MONTH STORECODE           DAY BILL_ID      BILL_AMT           QTY  \
# count   26895     26895  26895.000000   26895  26895.000000  26895.000000
# unique      3        10           NaN    6424           NaN           NaN
# top        M3        N7           NaN   T1521           NaN           NaN
# freq     9394      5602           NaN      44           NaN           NaN
# mean      NaN       NaN     15.163971     NaN    278.847163      4.114854
# std       NaN       NaN      8.960140     NaN    542.012679     95.826730
# min       NaN       NaN      1.000000     NaN      0.000000      0.500000
# 25%       NaN       NaN      7.000000     NaN     40.000000      1.000000
# 50%       NaN       NaN     14.000000     NaN    111.000000      1.000000
# 75%       NaN       NaN     23.000000     NaN    280.000000      2.000000
# max       NaN       NaN     31.000000     NaN   7292.000000  12000.000000
#
#                VALUE         PRICE                         GRP           SGRP  \
# ...

# %%
df1['UNIQUE_BILL ID']=df1['STORECODE']+df1['BILL_ID']
# Out:
# <ipython-input-27-c3ad37a1e831>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['UNIQUE_BILL ID']=df1['STORECODE']+df1['BILL_ID']

# %%
bill_count=df1.groupby("UNIQUE_BILL ID")['VALUE'].sum().reset_index()
bill_count
# Out:
#       UNIQUE_BILL ID   VALUE
# 0           N10T1038    34.0
# 1           N10T1039    46.0
# 2           N10T1040    86.0
# 3           N10T1043    20.0
# 4           N10T1048   180.0
# ...              ...     ...
# 13486         N9T940   200.0
# 13487          N9T95    56.0
# 13488         N9T953  1656.0
# 13489          N9T96   160.0
# 13490          N9T99   170.0
#
# [13491 rows x 2 columns]

# %%
df1.dtypes
# Out:
# MONTH              object
# STORECODE          object
# DAY                 int64
# BILL_ID            object
# BILL_AMT          float64
# QTY               float64
# VALUE             float64
# PRICE             float64
# GRP                object
# SGRP               object
# SSGRP              object
# CMP                object
# MBRD               object
# BRD                object
# UNIQUE_BILL ID     object
# dtype: object

# %%
def remove_character(column):
    return column.str.replace('M', '')

df1['MONTH'] = remove_character(df1['MONTH'])
df1['MONTH'] = df1['MONTH'].astype(int)

# %%
df1
# Out:
#        MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  VALUE  PRICE  \
# 0          1        N1    4    T375     225.0  1.0  225.0  225.0
# 1          1        N1    4    T379      95.0  1.0   95.0   95.0
# 2          1        N1    4    T381      10.0  1.0   10.0   10.0
# 3          1        N1    4    T382     108.0  1.0  108.0  108.0
# 4          1        N1    4    T384      19.0  1.0   19.0   19.0
# ...      ...       ...  ...     ...       ...  ...    ...    ...
# 26980      3       N10   31   T5999      10.0  1.0   10.0   10.0
# 26981      3       N10   31   T6007      88.0  1.0   10.0   10.0
# 26982      3       N10   31   T6007      88.0  2.0   20.0   10.0
# 26983      3       N10   31   T6007      88.0  1.0   58.0   58.0
# 26984      3       N10   31   T6013      15.0  1.0   15.0   15.0
#
#                               GRP                     SGRP  \
# 0            BUTTER MARGR  (4/94)                   BUTTER
# 1         CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df1['STORECODE'] = label_encoder.fit_transform(df1['STORECODE'])+1

# %%
df1
# Out:
#        MONTH  STORECODE  DAY BILL_ID  BILL_AMT  QTY  VALUE  PRICE  \
# 0          1          1    4    T375     225.0  1.0  225.0  225.0
# 1          1          1    4    T379      95.0  1.0   95.0   95.0
# 2          1          1    4    T381      10.0  1.0   10.0   10.0
# 3          1          1    4    T382     108.0  1.0  108.0  108.0
# 4          1          1    4    T384      19.0  1.0   19.0   19.0
# ...      ...        ...  ...     ...       ...  ...    ...    ...
# 26980      3          2   31   T5999      10.0  1.0   10.0   10.0
# 26981      3          2   31   T6007      88.0  1.0   10.0   10.0
# 26982      3          2   31   T6007      88.0  2.0   20.0   10.0
# 26983      3          2   31   T6007      88.0  1.0   58.0   58.0
# 26984      3          2   31   T6013      15.0  1.0   15.0   15.0
#
#                               GRP                     SGRP  \
# 0            BUTTER MARGR  (4/94)                   BUTTER
# ...

# %%
df1.dtypes
# Out:
# MONTH          int64
# STORECODE      int64
# DAY            int64
# BILL_ID       object
# BILL_AMT     float64
# QTY          float64
# VALUE        float64
# PRICE        float64
# GRP           object
# SGRP          object
# SSGRP         object
# CMP           object
# MBRD          object
# BRD           object
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
continuous_features = ['QTY', 'VALUE', 'PRICE']
for feature in continuous_features:
    sns.kdeplot(df1[feature], shade=True, label=feature)
plt.title('KDE Plot of Continuous Features')
plt.xlabel('Value')
plt.ylabel('Density')
plt.xlim(0, 500)
plt.legend()
plt.show()
# Out:
# <ipython-input-64-582684961dcf>:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df1[feature], shade=True, label=feature)
# <ipython-input-64-582684961dcf>:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df1[feature], shade=True, label=feature)
# <ipython-input-64-582684961dcf>:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df1[feature], shade=True, label=feature)

# %%
numericalvalues=[feature for feature in df1.columns if df1[feature].dtypes!='O']
df1[numericalvalues]
# Out:
#        MONTH  STORECODE  DAY  BILL_AMT  QTY  VALUE  PRICE
# 0          1          1    4     225.0  1.0  225.0  225.0
# 1          1          1    4      95.0  1.0   95.0   95.0
# 2          1          1    4      10.0  1.0   10.0   10.0
# 3          1          1    4     108.0  1.0  108.0  108.0
# 4          1          1    4      19.0  1.0   19.0   19.0
# ...      ...        ...  ...       ...  ...    ...    ...
# 26980      3          2   31      10.0  1.0   10.0   10.0
# 26981      3          2   31      88.0  1.0   10.0   10.0
# 26982      3          2   31      88.0  2.0   20.0   10.0
# 26983      3          2   31      88.0  1.0   58.0   58.0
# 26984      3          2   31      15.0  1.0   15.0   15.0
#
# [26985 rows x 7 columns]

# %%
for column in numericalvalues:
  print(column)
  plt.subplot(1,2,1)
  plt.hist(df1[column])
  plt.show()
  plt.subplot(1,2,2)
  sns.boxplot(x=df1[column])
  plt.show()
# Out:
# MONTH
# STORECODE
# DAY
# BILL_AMT
# QTY
# VALUE
# PRICE

# %%
fig, axes = plt.subplots(3, 2, figsize = (18, 18))
fig.suptitle('Bar plot for all categorical variables')
sns.countplot(ax = axes[0, 0], x = 'GRP', data = df1,
              order = df1['GRP'].head(20).value_counts().index);
sns.countplot(ax = axes[0, 1], x = 'SGRP', data = df1,
              order = df1['SGRP'].head(20).value_counts().index);
sns.countplot(ax = axes[1, 0], x = 'SSGRP', data = df1,
              order = df1['SSGRP'].head(20).value_counts().index);
sns.countplot(ax = axes[1, 1], x = 'CMP', data = df1,
              order = df1['CMP'].head(20).value_counts().index);
sns.countplot(ax = axes[2, 0], x = 'MBRD', data = df1,
              order = df1['MBRD'].head(20).value_counts().index);
sns.countplot(ax = axes[2, 1], x = 'BRD', data = df,
              order = df1['BRD'].head(20).value_counts().index);
for ax in axes.flatten():
    ax.tick_params(labelrotation=90)
plt.show()

# %%
df1[numericalvalues].corr()
# Out:
#               MONTH  STORECODE       DAY  BILL_AMT       QTY     VALUE  \
# MONTH      1.000000   0.022654  0.017447 -0.024162  0.012371 -0.005994
# STORECODE  0.022654   1.000000  0.005567  0.155763 -0.022305  0.109713
# DAY        0.017447   0.005567  1.000000 -0.048808  0.008431 -0.027509
# BILL_AMT  -0.024162   0.155763 -0.048808  1.000000  0.027484  0.460631
# QTY        0.012371  -0.022305  0.008431  0.027484  1.000000  0.067245
# VALUE     -0.005994   0.109713 -0.027509  0.460631  0.067245  1.000000
# PRICE      0.004806   0.109940 -0.021367  0.350307 -0.018326  0.791834
#
#               PRICE
# MONTH      0.004806
# STORECODE  0.109940
# DAY       -0.021367
# BILL_AMT   0.350307
# QTY       -0.018326
# VALUE      0.791834
# PRICE      1.000000

# %%
Overall_sales_per_month= df1.groupby('MONTH')['VALUE'].sum()
Overall_sales_per_month.plot(kind='line', marker='o', linestyle='-')
plt.xlabel('Month')
plt.ylabel('Overall Sales')
plt.title('Overall Sales per Month')
plt.show()

# %%
Overall_sales_per_store= df1.groupby('STORECODE')['VALUE'].sum()
Overall_sales_per_store.plot(kind='line', marker='o', linestyle='-')
plt.xlabel('STORECODE')
plt.ylabel('Overall Sales')
plt.title('Overall Sales per Month')
plt.show()

# %%
average_sales=df1.groupby('STORECODE')["VALUE"].mean().reset_index()
average_sales
# Out:
#    STORECODE       VALUE
# 0          1   31.465619
# 1          2   65.667589
# 2          3  166.307288
# 3          4   70.010480
# 4          5   64.406908
# 5          6   53.725344
# 6          7   92.984810
# 7          8   48.673271
# 8          9  103.250762
# 9         10  164.212716

# %%
average_sales.plot(kind='bar',x='STORECODE',y='VALUE')
plt.title('Average Sales per Store')
plt.xlabel('Store')
plt.ylabel('Average Sales')
plt.show()

# %%
sales_per_store = df1.groupby('STORECODE')['VALUE'].sum().reset_index()
sales_per_store.sort_values(by='VALUE',ascending=False,inplace=True)
sales_per_store
# Out:
#    STORECODE      VALUE
# 7          8  273787.15
# 9         10  250917.03
# 5          6  238057.00
# 2          3  221355.00
# 4          5  206874.99
# 0          1  144206.93
# 1          2  142433.00
# 3          4  125528.79
# 8          9  116466.86
# 6          7  110187.00

# %%
plt.pie(sales_per_store['VALUE'],labels=sales_per_store['STORECODE'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7e9ac9e709a0>,
# ...
#  [Text(0.9806937476393118, 0.4982366639872683, '8'),
#   Text(0.21839934314424272, 1.078100981779612, '10'),
#   Text(-0.6565995687111267, 0.8825400876834789, '6'),
#   Text(-1.0888671577218996, 0.15610353242201874, '3'),
#   Text(-0.912298146751577, -0.6145828596972406, '5'),
#   Text(-0.403099365867597, -1.0234798001119227, '1'),
#   Text(0.1283353278711236, -1.09248800616767, '2'),
#   Text(0.6000598047427655, -0.9219155225572863, '4'),
#   Text(0.9211205174132004, -0.6012794628127907, '9'),
#   Text(1.0803747353901378, -0.2068584809252206, '7')],
#  [Text(0.5349238623487155, 0.2717654530839645, '15.0%'),
#   Text(0.11912691444231419, 0.5880550809706975, '13.7%'),
#   Text(-0.3581452192969781, 0.48138550237280664, '13.0%'),
#   Text(-0.5939275405755815, 0.08514738132110113, '12.1%'),
#   Text(-0.4976171709554056, -0.33522701438031305, '11.3%'),
#   Text(-0.2198723813823256, -0.5582617091519578, '7.9%'),
# ...

# %%
sales_by_month_day = df1.groupby(['MONTH', 'DAY'])['VALUE'].sum().reset_index()
sales_by_month_day
# Out:
#     MONTH  DAY     VALUE
# 0       1    1  19878.58
# 1       1    2  25006.00
# 2       1    3  23611.51
# 3       1    4  31192.53
# 4       1    5  26698.85
# ..    ...  ...       ...
# 88      3   27  11606.35
# 89      3   28  26770.69
# 90      3   29  16870.46
# 91      3   30  19618.30
# 92      3   31  11531.06
#
# [93 rows x 3 columns]

# %%
sales_by_month_day_m1 = sales_by_month_day[sales_by_month_day['MONTH'] == 1]
sales_by_month_day_m2 = sales_by_month_day[sales_by_month_day['MONTH'] == 2]
sales_by_month_day_m3 = sales_by_month_day[sales_by_month_day['MONTH'] == 3]

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.fill_between(sales_by_month_day_m1['DAY'], sales_by_month_day_m1['VALUE'], alpha=0.5, label='M1',color="violet")
ax.fill_between(sales_by_month_day_m2['DAY'], sales_by_month_day_m2['VALUE'], alpha=0.5, label='M2',color="lightpink")
ax.fill_between(sales_by_month_day_m3['DAY'], sales_by_month_day_m3['VALUE'], alpha=0.5, label='M3',color="skyblue")
ax.set_xlabel('Day')
ax.set_ylabel('Total Sales')
ax.set_title('Total Sales by Month and Day')
ax.legend()
ax.grid(True,color='whitesmoke')
plt.tight_layout()
plt.show()

# %%
total_pro=df.groupby('STORECODE')['QTY'].sum().reset_index()
total_pro
# Out:
#    STORECODE    QTY
# 0          0  18526
# 1          1  21323
# 2          2  10483
# 3          3  27602
# 4          4  34089
# 5          5  25993
# 6          6  21178
# 7          7  21114
# 8          8  32003
# 9          9  20904

# %%
plt.pie(total_pro['QTY'],labels=total_pro['STORECODE'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7e9ac8c19270>,
# ...
#  [Text(1.0659232939596208, 0.271675415513204, '0'),
#   Text(0.7770705587320578, 0.7785636433534818, '1'),
#   Text(0.38336628939407563, 1.0310336018560298, '2'),
#   Text(-0.17204496896970148, 1.0864623917339313, '3'),
#   Text(-0.9184658870873244, 0.6053267004328279, '4'),
#   Text(-1.0718713921081073, -0.2471673902039428, '5'),
#   Text(-0.7159592084718488, -0.8351062278562914, '6'),
#   Text(-0.1524357698850974, -1.0893866788517004, '7'),
#   Text(0.5996051056352713, -0.9222113192192533, '8'),
#   Text(1.056675188311293, -0.30567555742534175, '9')],
#  [Text(0.5814127057961567, 0.14818659027992945, '7.9%'),
#   Text(0.4238566683993042, 0.4246710781928082, '9.1%'),
#   Text(0.20910888512404122, 0.5623819646487435, '4.5%'),
#   Text(-0.09384271034710988, 0.5926158500366898, '11.8%'),
#   Text(-0.5009813929567223, 0.3301782002360879, '14.6%'),
#   Text(-0.5846571229680585, -0.13481857647487788, '11.1%'),
# ...

# %%
df1
# Out:
#        MONTH  STORECODE  DAY BILL_ID  BILL_AMT  QTY  VALUE  PRICE  \
# 0          1          1    4    T375     225.0  1.0  225.0  225.0
# 1          1          1    4    T379      95.0  1.0   95.0   95.0
# 2          1          1    4    T381      10.0  1.0   10.0   10.0
# 3          1          1    4    T382     108.0  1.0  108.0  108.0
# 4          1          1    4    T384      19.0  1.0   19.0   19.0
# ...      ...        ...  ...     ...       ...  ...    ...    ...
# 26980      3          2   31   T5999      10.0  1.0   10.0   10.0
# 26981      3          2   31   T6007      88.0  1.0   10.0   10.0
# 26982      3          2   31   T6007      88.0  2.0   20.0   10.0
# 26983      3          2   31   T6007      88.0  1.0   58.0   58.0
# 26984      3          2   31   T6013      15.0  1.0   15.0   15.0
#
#                               GRP                     SGRP  \
# 0            BUTTER MARGR  (4/94)                   BUTTER
# ...

# %%
most_bought_product = df1['GRP'].value_counts().idxmax()
frequency = df1['GRP'].value_counts().max()

print(f"The most bought product is '{most_bought_product}' with a frequency of {frequency}.")
# Out:
# The most bought product is 'BISCUITS - CORE & NON CORE' with a frequency of 6677.

# %%
most_bought_product_in_each_store = df1.groupby(['STORECODE', 'GRP'])['QTY'].sum().sort_values(ascending=False).reset_index()
most_bought_product_in_each_store.head(50)
# Out:
#     STORECODE                             GRP      QTY
# 0           1   REFINED EDIBLE OILS-ALL PACKS  32108.0
# 1           3               CLEANERS - TOILET   8027.0
# 2           8            HAIR OILS PKTP(8/02)   6037.0
# 3           8   REFINED EDIBLE OILS-ALL PACKS   3403.0
# 4           3   REFINED EDIBLE OILS-ALL PACKS   3057.0
# 5           3              PACKAGED PURE GHEE   3021.0
# 6           6      BISCUITS - CORE & NON CORE   2691.0
# 7           5      BISCUITS - CORE & NON CORE   2081.0
# 8           3              CLEANERS - UTENSIL   2076.0
# 9           3   HOME INSECTICIDES CTG  (8/93)   2023.0
# 10          8      BISCUITS - CORE & NON CORE   1894.0
# 11          1      BISCUITS - CORE & NON CORE   1768.0
# 12          3      BISCUITS - CORE & NON CORE   1619.0
# 13          2      BISCUITS - CORE & NON CORE   1333.0
# 14          5         WASHING POWDERS/LIQUIDS   1171.0
# 15          3     LIQUID TOILET SOAPS  (8/93)   1020.0
# ...
